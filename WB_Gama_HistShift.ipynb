# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
from wb import *

# %%
img = readImg("DatasetPropio/ciudad.jpg")
#img = readImg("5D - part 1/102_IMG_0298.tiff")

# %%
showImg(img,10)
# Out:
# (665, 1000, 3)
# Brightness %: 44.105857585139326

# %%
plotHists(img,10)

# %%
g = calcGamma(img)
img = adjust_gamma(img,g)
showImg(img,10)
# Out:
# Brightness %: 44.105857585139326
# Brightness %: 46.96017219519387
# Brightness %: 49.765864661654135
# Brightness %: 52.269931888544896
# Brightness %: 54.540072534276874
# Brightness %: 56.596467639687454
# Brightness %: 58.50123956951201
# Brightness %: 60.238445525578655
# Brightness %: 61.84494176618015
# Brightness %: 63.31763585434174
# 1.9000000000000008
# (665, 1000, 3)
# Brightness %: 63.31763585434174

# %%
plotHists(img,10)

# %%
k = constraint(img)
# Out:
# Brightness %: 63.31763585434174
# Brightness %: 63.31763585434174
# Brightness %: 56.808545481350436
# Brightness %: 50.49576529559192
# 0.8

# %%
imgUp = updImg(img,k)

# %%
showImg(imgUp,10)
# Out:
# (665, 1000, 3)
# Brightness %: 50.49576529559192

# %%
plotHists(imgUp,10)

# %%
img2 = shiftHist(imgUp)
# Out:
# 74.65531428571428	92.49517744360902	128.76035488721806
# -17.83986315789474	36.26517744360903

# %%
showImg(img2,10)
# Out:
# (665, 1000, 3)
# Brightness %: 38.837253132832075

# %%
plotHists(img2,10)
