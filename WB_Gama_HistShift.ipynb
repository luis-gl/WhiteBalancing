# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from wb import *

# %%
img = readImg("DatasetPropio/asd.jpg")
#img = readImg("5D - part 1/100_IMG_0296.tiff")

# %%
showImg(img,10)
# Out:
# (1024, 1536, 3)
# Brightness %: 67.99928054310917

# %%
plotHists(img,10)

# %%
g = calcGamma(img)
img = adjust_gamma(img,g)
showImg(img,10)
# Out:
# Brightness %: 67.99928054310917
# Brightness %: 69.51135099323747
# Brightness %: 71.10802669151155
# Brightness %: 72.54587510052849
# Brightness %: 73.81907219980278
# Brightness %: 74.9825576084112
# Brightness %: 76.06738620334201
# Brightness %: 77.07218294829326
# Brightness %: 77.97192966236788
# Brightness %: 78.81084890926586
# 1.9000000000000008
# (1024, 1536, 3)
# Brightness %: 78.81084890926586

# %%
plotHists(img,10)

# %%
k = constraint(img)
# Out:
# Brightness %: 78.81084890926586
# Brightness %: 78.81084890926586
# Brightness %: 70.75246075399562
# Brightness %: 62.8945608700023
# 0.8

# %%
imgUp = updImg(img,k)

# %%
showImg(imgUp,10)
# Out:
# (1024, 1536, 3)
# Brightness %: 62.8945608700023

# %%
plotHists(imgUp,10)

# %%
img2 = shiftHist(imgUp)
# Out:
# 132.5745417277018	138.70915031433105	160.3810272216797
# -6.134608586629241	21.671876907348633

# %%
showImg(img2,10)
# Out:
# (1024, 1536, 3)
# Brightness %: 56.66523852379493

# %%
plotHists(img2,10)

# %%
#saveImg(img2, 'test1')
#saveImg(img3, 'test2')
